# %%
# %load_ext autoreload
# %autoreload 2

from substrata import *


plot = initializer.ProjectInitializer(path='/mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008')
plot.initialize()
# Out:
# Loading pointcloud from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_dec50M.ply
# Loading cameras from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008.meta.json and /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008.cams.xml
# Loading markers from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_markers.csv
# Loading annotations from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_intercepts.csv

# %%
plot = initializer.ProjectInitializer(path='/mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008')
plot.initialize()
plot.pcd.apply_along_slope_transform(visualize=True)
# Out:
# Loading pointcloud from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_dec50M.ply
# Loading cameras from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008.meta.json and /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008.cams.xml
# Loading markers from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_markers.csv
# Loading annotations from /mnt/sdd/tonga_focal/ton_tof/ton_tof_40m/ton_tof_40m_20241008/ton_tof_40m_20241008_intercepts.csv
# Inlier method: PCA (deterministic)
# Original PCA/SVD normal vector: [0.060494, -0.638928, 0.766885]
# Original PCA/SVD normal elevation: 39.925°
# Final world_transform after along slope transform:
# [[ 1.37209189e-02 -2.69508222e-01  4.14407704e-02  1.72208529e+01]
#  [ 2.15691267e-01  3.61126773e-02  1.63442450e-01  8.96900566e+00]
#  [-1.66821151e-01  2.45249996e-02  2.14731252e-01 -3.88705911e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# (array([ 0.06049412, -0.63892755,  0.76688463]), 39.92504993766269)

# %%
ann = Annotation([-0.329725742,	-36.19788742, -5.783945084])
ann.get_image_matches(plot.cams, pcd=plot.pcd, debug=True)
for match in ann.image_matches:
    match.show()
# Out:
# Pixel coordinates for camera 0: 2441, 5216, 7.066338021164584, 0.018752684068401877
# Pixel coordinates for camera 1: 1963, 5362, 6.503210317832434, 0.02088684972842021
# Pixel coordinates for camera 2: 1252, 4620, 6.195905280327661, 0.020427457021083964
# Pixel coordinates for camera 3: 248, 4673, 4.8321280391715735, 0.023202031744951862
# Pixel coordinates for camera 4: 171, 4731, 3.9975678381880604, 0.0227869225137715
# Pixel coordinates for camera 5: 678, 4758, 3.7006421805124172, 0.020629543812516287
# Pixel coordinates for camera 6: 416, 5133, 3.9102488136260933, 0.023203236356634887
# Pixel coordinates for camera 7: 619, 5187, 5.027160548338324, 0.02358969250723074
# Pixel coordinates for camera 8: 1036, 5615, 5.290068265180294, 0.024257037558733756
# Pixel coordinates for camera 9: 1163, 5471, 5.56303516055904, 0.023588093482865474
# Pixel coordinates for camera 10: 1161, 5459, 5.527018831172743, 0.023206526399564154
# Pixel coordinates for camera 11: 1137, 6018, 5.094287774937437, 0.025491852442719183
# Pixel coordinates for camera 196: 8872, 576, 2.9941814608964044, 0.010801794180262505
# Pixel coordinates for camera 197: 8947, 906, 2.943615825906109, 0.009415653944001734
# Pixel coordinates for camera 198: 7185, 2329, 4.062155130900458, 0.004317607404832458
# Pixel coordinates for camera 199: 8600, 2686, 3.3887455556500714, 0.005730996035312626
# Pixel coordinates for camera 202: 9190, 5078, 2.4850617931939905, 0.009585042614334176
# Pixel coordinates for camera 203: 8947, 5812, 2.7229824779572707, 0.011249597008424062
# Pixel coordinates for camera 225: 7496, 1117, 3.240399992889948, 0.005088396907462168
# Warning: no neighboring point found
# Pixel coordinates for camera 226: 7045, 2040, 3.320301307052353, 0.0031061425121739618
# Warning: no neighboring point found
# Pixel coordinates for camera 227: 5983, 2869, 3.5498916321468115, 0.0013066012474941052
# Pixel coordinates for camera 228: 5403, 3793, 3.482978823410712, 0.0010273458329982709
# Pixel coordinates for camera 229: 7342, 4539, 3.073857078947531, 0.0034008286875521496
# Pixel coordinates for camera 307: 2801, 672, -51.09742167073836, 0.938677588376207
# Pixel coordinates for camera 453: 1031, 4341, 5.138123843768586, 0.03626306332288809
# Pixel coordinates for camera 468: 635, 5870, 7.441813471666062, 0.07962977943075032
# Pixel coordinates for camera 469: 489, 5615, 8.042960018718363, 0.08106861084278381
# Pixel coordinates for camera 470: 1365, 5638, 6.900147041399398, 0.07464897742851645
# Pixel coordinates for camera 601: 715, 424, 30.144557674592185, 1.334624221795059
# Warning: no neighboring point found
# Pixel coordinates for camera 602: 465, 732, 32.34806088557883, 1.289772891996235
# Warning: no neighboring point found
# Pixel coordinates for camera 603: 1045, 1286, 26.498334350824642, 1.0344321511391645
# Pixel coordinates for camera 604: 1011, 1550, 25.924198750200077, 0.9605643339653629
# Pixel coordinates for camera 609: 1908, 572, 23.531583354518656, 0.8273397492389136
# Pixel coordinates for camera 634: 2216, 57, 24.585861632647894, 0.3712781439914978
# Pixel coordinates for camera 635: 1712, 457, 23.868428436579002, 0.3658254765363859
# Pixel coordinates for camera 636: 1003, 582, 20.883583985961806, 0.3845551057487971
# Pixel coordinates for camera 637: 539, 573, 17.25335693940898, 0.3901126904502406
# Pixel coordinates for camera 661: 9487, 1651, 5.3027995762745785, 0.03716665842852821
# Pixel coordinates for camera 664: 9379, 2732, 5.434910571079894, 0.022538269277486433
# Pixel coordinates for camera 667: 9294, 3130, 5.443564011423549, 0.019423309597874555
# Pixel coordinates for camera 668: 9330, 3284, 5.419941245248068, 0.020105340769836864
# Pixel coordinates for camera 669: 9121, 3498, 5.669940481485356, 0.020069414779290144
# Pixel coordinates for camera 670: 8543, 4010, 6.094160775546714, 0.018804999736227943
# Pixel coordinates for camera 671: 8172, 4553, 6.140990009129105, 0.01858571615030767
# Pixel coordinates for camera 672: 8346, 5287, 5.578115808442748, 0.021813244891607787
# Pixel coordinates for camera 673: 7992, 5398, 5.8366284409117455, 0.020886601117369116
# Pixel coordinates for camera 674: 8148, 6275, 5.110679586912294, 0.025377951468069274
